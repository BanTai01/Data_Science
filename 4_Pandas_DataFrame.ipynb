# %% [markdown]
# <a href="https://colab.research.google.com/github/BanTai01/Data_Science/blob/main/4_Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
employee_data_table = {
    "height": [5.5, 5.5, 6.0,5.8],
    "Weight": [57, 62, 72, 75],
    "bmi": [19.3, 12.7, 20.3, 18.5]

}

# %%
health_df = pd.DataFrame(employee_data_table)

# %%
print(type(health_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
health_df.head(3)
# Out:
#    height  Weight   bmi
# 0     5.5      57  19.3
# 1     5.5      62  12.7
# 2     6.0      72  20.3

# %%
health_df.tail(2)
# Out:
#    height  Weight   bmi
# 2     6.0      72  20.3
# 3     5.8      75  18.5

# %%
health_df.shape
health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  4 non-null      float64
#  1   Weight  4 non-null      int64
#  2   bmi     4 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 228.0 bytes

# %%
health_df.describe()
# Out:
#          height    Weight        bmi
# count  4.000000   4.00000   4.000000
# mean   5.700000  66.50000  17.700000
# std    0.244949   8.42615   3.413698
# min    5.500000  57.00000  12.700000
# 25%    5.500000  60.75000  17.050000
# 50%    5.650000  67.00000  18.900000
# 75%    5.850000  72.75000  19.550000
# max    6.000000  75.00000  20.300000

# %%
health_df.values
# Out:
# array([[ 5.5, 57. , 19.3],
#        [ 5.5, 62. , 12.7],
#        [ 6. , 72. , 20.3],
#        [ 5.8, 75. , 18.5]])

# %%
print(health_df.columns)
print(type(health_df.columns))
# Out:
# Index(['height', 'Weight', 'bmi'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>

# %%
health_df.columns = ["Height (Feet)", "Weight (Kg)", "BMI"]

# %%
health_df.head()
# Out:
#    Height (Feet)  Weight (Kg)   BMI
# 0            5.5           57  19.3
# 1            5.5           62  12.7
# 2            6.0           72  20.3
# 3            5.8           75  18.5

# %%
health_df.to_csv("/content/my_saved_df.csv") # creating csv file from coded datasets

health_df.to_csv("C:\\Users\\zahid\\OneDrive\\Desktop\\Data_Science_BogoDev\\Data_Science\\Datasets\\my_saved_df.csv")

# %%
""" Read DataFrame from a file

there are number of file formats:
1. Text file (.txt)
2. Comma Separated Value file (.csv)
3. JSON file (.json)
"""
df = pd.read_csv("/content/homelessness.csv")

# %%
print(type(df))
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Unnamed: 0              region                 state  individuals  \
# 0           0  East South Central               Alabama       2570.0
# 1           1             Pacific                Alaska       1434.0
# 2           2            Mountain               Arizona       7259.0
# 3           3  West South Central              Arkansas       2280.0
# 4           4             Pacific            California     109008.0
# 5           5            Mountain              Colorado       7607.0
# 6           6         New England           Connecticut       2280.0
# 7           7      South Atlantic              Delaware        708.0
# 8           8      South Atlantic  District of Columbia       3770.0
# 9           9      South Atlantic               Florida      21443.0
#
#    family_members  state_pop
# 0           864.0    4887681
# 1           582.0     735139
# 2          2606.0    7158024
# 3           432.0    3009733
# ...

# %%
"""Sort Data"""
sorted_df_by_multi_cols = df.sort_values(
    by = ["region"],
    ascending=[True]
)
sorted_df_by_multi_cols.head(10)
# Out:
#     Unnamed: 0              region         state  individuals  family_members  \
# 35          35  East North Central          Ohio       6929.0          3320.0
# 49          49  East North Central     Wisconsin       2740.0          2167.0
# 22          22  East North Central      Michigan       5209.0          3142.0
# 13          13  East North Central      Illinois       6752.0          3891.0
# 14          14  East North Central       Indiana       3776.0          1482.0
# 0            0  East South Central       Alabama       2570.0           864.0
# 42          42  East South Central     Tennessee       6139.0          1744.0
# 24          24  East South Central   Mississippi       1024.0           328.0
# 17          17  East South Central      Kentucky       2735.0           953.0
# 38          38        Mid-Atlantic  Pennsylvania       8163.0          5349.0
#
#     state_pop
# 35   11676341
# 49    5807406
# 22    9984072
# 13   12723071
# 14    6695497
# 0     4887681
# ...

# %%
"""Sort Data"""
sorted_df_by_multi_cols = df.sort_values(
    by = ["region", "family_members"],
    ascending=[True, True]
)
sorted_df_by_multi_cols.head(10)
# Out:
#     Unnamed: 0              region        state  individuals  family_members  \
# 14          14  East North Central      Indiana       3776.0          1482.0
# 49          49  East North Central    Wisconsin       2740.0          2167.0
# 22          22  East North Central     Michigan       5209.0          3142.0
# 35          35  East North Central         Ohio       6929.0          3320.0
# 13          13  East North Central     Illinois       6752.0          3891.0
# 24          24  East South Central  Mississippi       1024.0           328.0
# 0            0  East South Central      Alabama       2570.0           864.0
# 17          17  East South Central     Kentucky       2735.0           953.0
# 42          42  East South Central    Tennessee       6139.0          1744.0
# 30          30        Mid-Atlantic   New Jersey       6048.0          3350.0
#
#     state_pop
# 14    6695497
# 49    5807406
# 22    9984072
# 35   11676341
# 13   12723071
# 24    2981020
# ...

# %%
new_df = df[['region', 'family_members']]

# %%
new_df.head(10)
# Out:
#                region  family_members
# 0  East South Central           864.0
# 1             Pacific           582.0
# 2            Mountain          2606.0
# 3  West South Central           432.0
# 4             Pacific         20964.0
# 5            Mountain          3250.0
# 6         New England          1696.0
# 7      South Atlantic           374.0
# 8      South Atlantic          3134.0
# 9      South Atlantic          9587.0

# %%
# Selecting coloumns

mask = df['region']== 'Mountain'
df_mountain = df[mask]
df_mountain.head(10)
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 2            2  Mountain     Arizona       7259.0          2606.0    7158024
# 5            5  Mountain    Colorado       7607.0          3250.0    5691287
# 12          12  Mountain       Idaho       1297.0           715.0    1750536
# 26          26  Mountain     Montana        983.0           422.0    1060665
# 28          28  Mountain      Nevada       7058.0           486.0    3027341
# 31          31  Mountain  New Mexico       1949.0           602.0    2092741
# 44          44  Mountain        Utah       1904.0           972.0    3153550
# 50          50  Mountain     Wyoming        434.0           205.0     577601

# %%
df_gt_10k = df[df['individuals']>10000]
df_gt_10k.head()
# Out:
#     Unnamed: 0              region       state  individuals  family_members  \
# 4            4             Pacific  California     109008.0         20964.0
# 9            9      South Atlantic     Florida      21443.0          9587.0
# 32          32        Mid-Atlantic    New York      39827.0         52070.0
# 37          37             Pacific      Oregon      11139.0          3337.0
# 43          43  West South Central       Texas      19199.0          6111.0
#
#     state_pop
# 4    39461588
# 9    21244317
# 32   19530351
# 37    4181886
# 43   28628666

# %%
df["total_pop"] = df['individuals'] + df["state_pop"]
df.head(10)
# Out:
#    Unnamed: 0              region                 state  individuals  \
# 0           0  East South Central               Alabama       2570.0
# 1           1             Pacific                Alaska       1434.0
# 2           2            Mountain               Arizona       7259.0
# 3           3  West South Central              Arkansas       2280.0
# 4           4             Pacific            California     109008.0
# 5           5            Mountain              Colorado       7607.0
# 6           6         New England           Connecticut       2280.0
# 7           7      South Atlantic              Delaware        708.0
# 8           8      South Atlantic  District of Columbia       3770.0
# 9           9      South Atlantic               Florida      21443.0
#
#    family_members  state_pop   total_pop
# 0           864.0    4887681   4890251.0
# 1           582.0     735139    736573.0
# 2          2606.0    7158024   7165283.0
# ...

# %%
new_df = df.query(
    "region == 'Pacific' and family_members < 10000"
)

# %%
new_df.head(10)
# Out:
#     Unnamed: 0   region       state  individuals  family_members  state_pop  \
# 1            1  Pacific      Alaska       1434.0           582.0     735139
# 11          11  Pacific      Hawaii       4131.0          2399.0    1420593
# 37          37  Pacific      Oregon      11139.0          3337.0    4181886
# 47          47  Pacific  Washington      16424.0          5880.0    7523869
#
#     total_pop
# 1    736573.0
# 11  1424724.0
# 37  4193025.0
# 47  7540293.0
